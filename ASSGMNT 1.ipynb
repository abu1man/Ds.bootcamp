# %%
# improting libiraries 
import pandas as pd
import numpy as np 
import seaborn as snb 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("D:\DAC\Ds.bootcamp\DATA\iris.dataCopy.csv")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
data["species"].value_counts()
# Out:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
#histogram 
data.hist(figsize = (4,7))
plt.tight_layout()
plt.show()

# %%
snb.boxplot(x="sepal_length", y="sepal_width", data= data)
plt.title("petal Distributuon of dataset")
plt.show()

# %%
# scattered-plot
# sepal_length VS sepal_width
snb.scatterplot(x="sepal_width", y="sepal_length", hue="species", data = data)
plt.title("A scatterPlot for the three different Species")
# Draw an arrow to the data point with the maximum sepal length
plt.arrow(data["sepal_length"].max(), data["sepal_width"].max(), -2, 2,
          head_width=0.4, head_length=0.3, color="red")
plt.show()

# %%
# scattered-plot
# petal_length VS petal_width
snb.scatterplot(x="petal_length", y="petal_width", hue="species", data = data)
plt.title("A scatterPlot for the three different Species")
# Draw an arrow to the data point with the maximum sepal length
plt.arrow(data["sepal_length"].max(), data["sepal_width"].max(), -2, 2,
          head_width=0.5, head_length=0.5, color="red")
plt.show()

# %%
encoder = LabelEncoder()

data.species = encoder.fit_transform(data.species)

# %%
#corelation

# Create a heatmap of the correlation matrix
snb.heatmap(data.corr(), annot=True, cmap="coolwarm")

# Set the title
plt.title("Correlation Matrix of the Iris Dataset", fontdict={"fontsize": 16})

# Set the x-axis label
plt.xlabel("Features", fontdict={"fontsize": 14})

# Set the y-axis label
plt.ylabel("Features", fontdict={"fontsize": 14})

# Add a legend
plt.legend(title="Species", labels=["Setosa", "Versicolor", "Virginica"], fontsize=12)

# Show the plot
plt.show()

# %%
# bar chart
snb.countplot(x="species", data=data)
plt.title("Barchart")
plt.show()

# %%
# pie chart
plt.pie(data["species"].value_counts(), labels=data["species"].unique())
plt.title("Piechart")
plt.show()

# %%
#  Adding Title
plt.title("Flower sampling")

# Adding axes labels
plt.xlabel("Measurement values ")
plt.ylabel("Number of Flowers ")
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Create a list of features
ft = ["sepal_length", "sepal_width", "petal_length", "petal_width"]

# Iterate over each feature and create a violin plot
for ft in ft:
    snb.violinplot(y="species", x=ft, data=data, inner="quartile")
    
    plt.show()
